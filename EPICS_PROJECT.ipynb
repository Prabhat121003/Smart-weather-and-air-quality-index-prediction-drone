# %%
# importing pandas module for data frame
import pandas as pd

# loading dataset and storing in train variable
train=pd.read_csv('/content/drive/MyDrive/datasets/station_day.csv')

# display top 5 data
train.head()
# Out:
#   StationId        Date  PM2.5    PM10    NO    NO2    NOx    NH3    CO  \
# 0     AP001  2017-11-24  71.36  115.75  1.75  20.65  12.40  12.19  0.10
# 1     AP001  2017-11-25  81.40  124.50  1.44  20.50  12.08  10.72  0.12
# 2     AP001  2017-11-26  78.32  129.06  1.26  26.00  14.85  10.28  0.14
# 3     AP001  2017-11-27  88.76  135.32  6.60  30.85  21.77  12.91  0.11
# 4     AP001  2017-11-28  64.18  104.09  2.56  28.07  17.01  11.42  0.09
#
#      SO2      O3  Benzene  Toluene  Xylene    AQI AQI_Bucket
# 0  10.76  109.26     0.17     5.92    0.10    NaN        NaN
# 1  15.24  127.09     0.20     6.50    0.06  184.0   Moderate
# 2  26.96  117.44     0.22     7.95    0.08  197.0   Moderate
# 3  33.59  111.81     0.29     7.63    0.12  198.0   Moderate
# 4  19.00  138.18     0.17     5.02    0.07  188.0   Moderate

# %%
train.tail()
# Out:
#          PM2.5    PM10      NO    NO2     NOx    NH3    CO    SO2     O3  \
# 106143   80.93  174.84   82.96  56.74  139.70  29.32  1.18   9.36  15.96
# 106144  103.75  217.89  139.58  63.28  181.55  27.56  1.71  11.43  24.75
# 106145  115.40  225.76  193.19  70.41  213.77  35.25  2.11  10.49  22.11
# 106146   97.37  179.87  105.12  64.34  169.46  36.24  1.51   6.90  12.55
# 106147   89.13  179.89   78.47  56.37  134.84  37.98  1.30   8.13  23.21
#
#         Benzene  Toluene  Xylene    AQI
# 106143    53.71    51.38    1.30  179.0
# 106144    53.58    55.10    2.29  226.0
# 106145    58.61    61.42    3.20  259.0
# 106146    64.90    62.12    2.16  250.0
# 106147    69.67    66.15    2.42  223.0

# %%
train = train.drop(["StationId"], axis = 1)
train = train.drop(["Date"], axis = 1)
train = train.drop(["AQI_Bucket"], axis = 1)

# %%
train = train.dropna()

# %%
print(train.isna().sum())
# Out:
# PM2.5      0
# PM10       0
# NO         0
# NO2        0
# NOx        0
# NH3        0
# CO         0
# SO2        0
# O3         0
# Benzene    0
# Toluene    0
# Xylene     0
# AQI        0
# dtype: int64

# %%
train.head()
# Out:
#    PM2.5    PM10    NO    NO2    NOx    NH3    CO    SO2      O3  Benzene  \
# 1  81.40  124.50  1.44  20.50  12.08  10.72  0.12  15.24  127.09     0.20
# 2  78.32  129.06  1.26  26.00  14.85  10.28  0.14  26.96  117.44     0.22
# 3  88.76  135.32  6.60  30.85  21.77  12.91  0.11  33.59  111.81     0.29
# 4  64.18  104.09  2.56  28.07  17.01  11.42  0.09  19.00  138.18     0.17
# 5  72.47  114.84  5.23  23.20  16.59  12.25  0.16  10.55  109.74     0.21
#
#    Toluene  Xylene    AQI
# 1     6.50    0.06  184.0
# 2     7.95    0.08  197.0
# 3     7.63    0.12  198.0
# 4     5.02    0.07  188.0
# 5     4.71    0.08  173.0

# %%
# importing Randomforest
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import RandomForestRegressor

# creating model
m1 = RandomForestRegressor()

# separating class label and other attributes
train1 = train.drop(['AQI'], axis=1)
target = train['AQI']

# Fitting the model
m1.fit(train1, target)
'''RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
					max_depth=None, max_features='auto', max_leaf_nodes=None,
					max_samples=None, min_impurity_decrease=0.0,
					min_impurity_split=None, min_samples_leaf=1,
					min_samples_split=2, min_weight_fraction_leaf=0.0,
					n_estimators=100, n_jobs=None, oob_score=False,
					random_state=None, verbose=0, warm_start=False)'''

# calculating the score and the score is 97.96360799890066%
m1.score(train1, target) * 100
# Out:
# 99.00415353480163

# %%
# predicting the model with other values (testing the data)
# so AQI is 123.71
m1.predict([[123, 45, 67, 34, 5, 0, 23, 13.00, 110.87, 0.22, 5.78, 0.08]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([260.15])

# %%
# Adaboost model
# importing module

# defining model
m2 = AdaBoostRegressor()

# Fitting the model
m2.fit(train1, target)

'''AdaBoostRegressor(base_estimator=None, learning_rate=1.0, loss='linear',
				n_estimators=50, random_state=None)'''

# calculating the score and the score is 96.15377360010211%
m2.score(train1, target)*100
# Out:
# 80.86528642258605

# %%
# predicting the model with other values (testing the data)
# so AQI is 94.42105263
m2.predict([[123, 45, 67, 34, 5, 0, 23, 13.00, 110.87, 0.22, 5.78, 0.08]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
#   warnings.warn(
# array([228.49588477])

# %% [markdown]
# Database taken from mp gov

# %%
import pandas as pd

# %%
BhopalTT = pd.read_csv("/content/drive/MyDrive/datasets/Bhopal T T Nagar  01-01-1970 000000 To 01-12-2023 235959.csv")

# %%
BhopalTT.head()
# Out:
#    #    Month  Bhopal, T T Nagar  PM10 (µg/m3)  \
# 0  1  2019-10                           130.30
# 1  2  2019-11                           188.70
# 2  3  2019-12                           162.37
# 3  4  2020-01                           142.65
# 4  5  2020-02                           141.87
#
#    Bhopal, T T Nagar  PM2.5 (µg/m3)  Bhopal, T T Nagar  NO (µg/m3)  \
# 0                             63.03                          10.65
# 1                             89.52                          13.71
# 2                             86.84                           7.53
# 3                             72.23                          10.56
# 4                             51.21                           7.95
#
#    Bhopal, T T Nagar  NO2 (µg/m3)  Bhopal, T T Nagar  NOX (ppb)  \
# 0                           40.24                         30.06
# 1                           49.83                         37.65
# 2                           55.54                         35.69
# ...
